# %%
"""
******************************************************************************
                     Text Adventure Game
                         January 2023
                     Priscilla Chacur
             Python for Data Analysts: Methods & Tools
                 Hult International Business School
******************************************************************************

    DocString:
    
    A) Introduction:
    This is a trivia game based on the F.R.I.E.N.D.S (1994).
    This game includes an introduction where you will choose a character to be 
    and your goal is to find the rest of your 5 friends around NYC. 
    For each friend you find, you pass on a stage. 
    
    There is only one correct answer to each question and you have 3 chances/
    lives to reunite everyone. You cannot repeat characters that have been 
    previously chosen.
    
    If you are able to get everyone together, you've proven you know your 
    friends really well and... YOU WIN!
    However, for each question that you get it wrong, you lose a life and 
    if you run out of lives, you lose the game :(
    
    Let's see if you are TRULY a F.R.I.E.N.D.S fan!
    
    B) Known Bugs or Errors:
    None.
    
    Source: 
    Crane, D & Kauffman, M (Executive Producers).  (1994).  \
    Friends [TV series].National Broadcasting Company.


"""
#importing random package to be used for selecting 
#questions for each character randomly, so that it changes if the player wants
#to play more than once
import random

#import package to exit the game
from sys import exit

print("*"*80) 

#Defining restarting function that allows the user to choose to play again
#This function is called when the player either wins the game by getting all
#characters together, or when the user loses all lives and therefore loses
#the game (similar to the fail() function)
def restart():
    while True:
        play_again = input(prompt = "\n" 
                "Do you want to play again? (Yes/No)").lower()

        if play_again == "yes":
    #if the user wants to play again, the intro() function
    #to restart the game is called
            intro()
        elif play_again == "no":
            print("\n"
                        "Thank you for playing!!"
                   "\n"
               "It was a pleasure! Come back anytime :)")
            exit()
            break
            
        else:
            print("Invalid input")

#In order to make the game interactive and make the user decides which 
#character to select next, a function for each character is created


#First character is joey with 2 questions that are randomly selected which 
#one will be pulled for the user
def joey():
    global user_lives
    global user_player
    #creating the random option with random.randint
    joey_questions = random.randint(0,1)
    if joey_questions == 0:
        print("What is Joey's last name? \n a. Travolta \n b. Cena"
        "c. Tribbiani")
        user_input = ""
        while user_input != "c":
            user_input = input(prompt="Select the correct answer:" 
              "(A, B or C)").lower()
            #if user input the incorrect answer, one life is removed for each
            #incorrect trial
            if user_input == "a" or user_input == "b":
                print("Good try, but unfortunately that's incorrect :(")
                user_lives -= 1
                #controlling that if the user no longer has any lives, the 
                #game is over and the restart function is called 
                if user_lives == 0:
                    print("You lost all your lives! Your friends will not be"
                    " reunited." 
                    "\n"
                    "Game over!")
                    restart()
            #determining the correct answer
            elif user_input == "c":
                print("Congrats! This is correct! You now got Joey with you!")
                #this function renames the user_player to the selected player,
                #in this case, joey. This is soon used to remove "joey" from
                #the characters list
                user_player = "joey"
            else:
                print("Invalid input."
                      "Please select one of the possible options (A/B/C)")
    #second option/question to be pulled from the random selection
    else:
        print("What catchphrase was Joey most known for? \n a. How you doin'?"
            "\n b. Alrighty! \n c. Pizza time!")
        user_input = ""
        while user_input != "a":
            user_input = input(prompt= 
                    "\n Select the correct answer: (A, B or C)").lower()
            if user_input == "b" or user_input == "c":
                print("Good try, but unfortunately that's incorrect :(")
                user_lives -= 1
                #controlling that if the user no longer has any lives, the 
                #game is over and the restart function is called 
                if user_lives == 0:
                    print("You lost all your lives!" 
                          "\n"
                     "Your friends will not be reunited"
                          "\n"
                    "Game over!")
                    restart()
            #determining the correct answer
            elif user_input == "a":
                print("Congrats! This is correct! You now got Joey with you!")
                #this function renames the user_player to the selected player,
                #in this case, joey. This is soon used to remove "joey" from
                #the characters list
                user_player = "joey"
            else:
                print("Invalid input."
                      "Please select one of the possible options (A/B/C)")
    #this statament is the function that removes the defined user_player above,
    #in this case, joey, from the characters list. This way, it avoids the user
    #to select the same character more than once as it will no longer going to
    #be available in the characters list
    characters.remove(user_player)
    
    
def monica():
    global user_lives
    global user_player
    #creating the random option with random.randint
    monica_questions = random.randint(0,1)
    if monica_questions  == 0:
        print("Chandler can't have kids, what does Monica decides to do"
            "regarding having kids? \n a. Sperm Donor \n b. Adopt"
            "\n c. Breaks up with Chandler")
        user_input = ""
        while user_input != "b":
            user_input = input(prompt="Select the correct answer:" 
                          "(A, B or C)").lower()
            if user_input == "a" or user_input == "c":
                print("Good try, but unfortunately that's incorrect :(")
                user_lives -= 1
                #controlling that if the user no longer has any lives, the 
                #game is over and the restart function is called 
                if user_lives == 0:
                    print("You lost all your lives! Your friends will not be"
                    " reunited." 
                    "\n"
                    "Game over!")
                    restart()
            #determining the correct answer
            elif user_input == "b":
                print("Congrats! This is correct! You now got Monica"
                "joining you!")
                #this function renames the user_player to the selected player,
                #in this case. This is soon used to remove from
                #the characters list
                user_player = "monica"
            else:
                print("Invalid input, please select one of the possible" 
                 "options (A/B/C)")
    #second option/question to be pulled from the random selection
    else:
        print("What was Monica's job? \n a. Waitress \n b. Singer \n c. Chef")
        user_input = ""
        while user_input != "c":
            user_input = input(prompt=
                        "Select the correct answer: (A, B or C)").lower()
            if user_input == "a" or user_input == "b":
                print("Good try, but unfortunately that's incorrect :(")
                user_lives -= 1
                #controlling that if the user no longer has any lives, the 
                #game is over and the restart function is called 
                if user_lives == 0:
                    print("You lost all your lives! Your friends will not be"
                    " reunited." 
                    "\n"
                    "Game over!")
                    restart()
            #determining the correct answer
            elif user_input == "c":
                print("Congrats! This is correct! You now got Monica with you!")
                #this function renames the user_player to the selected player,
                #in this case. This is soon used to remove from
                #the characters list
                user_player = "monica"
            else:
                print("Invalid input, please select one of the possible"
                "options (A/B/C)")
    #this statament is the function that removes the defined user_player above,
    #in this case from the characters list. This way, it avoids the user
    #to select the same character more than once as it will no longer going to
    #be available in the characters list
    characters.remove(user_player)
    
    
    
def ross():
    global user_lives
    global user_player
    #creating the random option with random.randint
    ross_questions = random.randint(0,1)
    if ross_questions  == 0:
        print("Possibly the most career oriented character, Ross takes his"
            " work very seriously. What does he do for a living? \n" 
            "a. Paleontologist \n b. Psychologist \n c. Doctor")
        user_input = ""
        while user_input != "a":
            user_input = input(prompt="Select the correct answer:" 
              "(A, B or C)").lower()
            if user_input == "b" or user_input == "c":
                print("Good try, but unfortunately that's incorrect :(")
                user_lives -= 1
                #controlling that if the user no longer has any lives, the 
                #game is over and the restart function is called 
                if user_lives == 0:
                    print("You lost all your lives! Your friends will not be"
                    " reunited." 
                    "\n"
                    "Game over!")
                    restart()
            #determining the correct answer
            elif user_input == "a":
                print("Congrats! This is correct! You now got Ross with you!")
                #this function renames the user_player to the selected player,
                #in this case. This is soon used to remove from
                #the characters list
                user_player = "ross"
            else:
                print("Invalid input."
                      "Please select one of the possible options (A/B/C)")
    #second option/question to be pulled from the random selection
    else:
        print("What was the name of Ross' monkey?"
              "\n a. Luke \n b. Marcel \n c. Ben")
        user_input = ""
        while user_input != "b":
            user_input = input(prompt="Select the correct answer:" 
              "(A, B or C)").lower()
            if user_input == "a" or user_input == "c":
                print("Good try, but unfortunately that's incorrect :(")
                user_lives -= 1
                #controlling that if the user no longer has any lives, the 
                #game is over and the restart function is called 
                if user_lives == 0:
                    print("You lost all your lives! Your friends will not be"
                    " reunited." 
                    "\n"
                    "Game over!")
                    restart()
            #determining the correct answer
            elif user_input == "b":
                print("Congrats! This is correct! You now got Ross with you!")
                #this function renames the user_player to the selected player,
                #in this case. This is soon used to remove from
                #the characters list
                user_player = "ross"
            else:
                print("Invalid input."
                      "Please select one of the possible options (A/B/C)")
    #this statament is the function that removes the defined user_player above,
    #in this case from the characters list. This way, it avoids the user
    #to select the same character more than once as it will no longer going to
    #be available in the characters list
    characters.remove(user_player)
    
def chandler():
    global user_lives
    global user_player
    #creating the random option with random.randint
    chandler_questions = random.randint(0,1)
    if chandler_questions  == 0:
        print("Which holiday does Chandler hates the most?"
              "\n a. Christmas \n b. Easter \n c. Thanksgiving")
        user_input = ""
        while user_input != "c":
            user_input = input(prompt="Select the correct answer:" 
              "(A, B or C)").lower()
            if user_input == "a" or user_input == "b":
                print("Good try, but unfortunately that's incorrect :(")
                user_lives -= 1
                #controlling that if the user no longer has any lives, the 
                #game is over and the restart function is called 
                if user_lives == 0:
                    print(
                    "You lost all your lives!" 
                          "\n"
                 "Your friends will not be reunited"
                          "\n"
                    "Game over!")
                    restart()
            #determining the correct answer
            elif user_input == "c":
                print("Congrats! This is correct!"
                      "You now got Chandler with you!")
                #this function renames the user_player to the selected player,
                #in this case. This is soon used to remove from
                #the characters list
                user_player = "chandler"
            else:
                print("Invalid input."
                      "Please select one of the possible options (A/B/C)")
    #second option/question to be pulled from the random selection
    else:
        print("What was Chandler's mom occupation in Las Vegas?"
              " \n a. Actress \n b. Engineer \n c. Model")
        user_input = ""
        while user_input != "a":
            user_input = input(prompt="Select the correct answer:" 
              "(A, B or C)").lower()
            if user_input == "b" or user_input == "c":
                print("Good try, but unfortunately that's incorrect :(")
                user_lives -= 1
                #controlling that if the user no longer has any lives, the 
                #game is over and the restart function is called 
                if user_lives == 0:
                    print("You lost all your lives! Your friends will not be"
                    " reunited." 
                    "\n"
                    "Game over!")
                    restart()
            #determining the correct answer
            elif user_input == "a":
                print("Congrats! This is correct!" 
                      "You now got Chandler with you!")
                #this function renames the user_player to the selected player,
                #in this case. This is soon used to remove from
                #the characters list
                user_player = "chandler"
            else:
                print("Invalid input."
                      "Please select one of the possible options (A/B/C)")
    #this statament is the function that removes the defined user_player above,
    #in this case from the characters list. This way, it avoids the user
    #to select the same character more than once as it will no longer going to
    #be available in the characters list
    characters.remove(user_player)

def rachel():
    global user_lives
    global user_player
    #creating the random option with random.randint
    rachel_questions = random.randint(0,1)
    if rachel_questions  == 0:
        print("Always in love with the fashion business, which of the"
              "following did Rachel NOT work in? \n a. Calvin Klein \n"
              "b. Ralph Lauren \n c. Bloomingdale's")
        user_input = ""
        while user_input != "a":
            user_input = input(prompt="Select the correct answer:" 
              "(A, B or C)").lower()
            if user_input == "b" or user_input == "c":
                print("Good try, but unfortunately that's incorrect :(")
                user_lives -= 1
                #controlling that if the user no longer has any lives, the 
                #game is over and the restart function is called 
                if user_lives == 0:
                    print("You lost all your lives! Your friends will not be"
                    " reunited." 
                    "\n"
                    "Game over!")
                    restart()
            #determining the correct answer
            elif user_input == "a":
                print("Congrats! This is correct! You now got Rachel with you!")
                #this function renames the user_player to the selected player,
                #in this case. This is soon used to remove from
                #the characters list
                user_player = "rachel"
            else:
                print("Invalid input."
                      "Please select one of the possible options (A/B/C)")
    #second option/question to be pulled from the random selection
    else:
        print("Rachel worked as a waitress in a coffee shop at first."
              "What was the name of the coffee shop?"
              "\n a. Starbucks \n b. New York's Best \n c. Central Perk")
        user_input = ""
        while user_input != "c":
            user_input = input(prompt="Select the correct answer:" 
              "(A, B or C)").lower()
            if user_input == "a" or user_input == "b":
                print("Good try, but unfortunately that's incorrect :(")
                user_lives -= 1
                #controlling that if the user no longer has any lives, the 
                #game is over and the restart function is called 
                if user_lives == 0:
                    print("You lost all your lives! Your friends will not be"
                    " reunited." 
                    "\n"
                    "Game over!")
                    restart()
            #determining the correct answer
            elif user_input == "c":
                print("Congrats! This is correct! You now got Rachel with you!")
                #this function renames the user_player to the selected player,
                #in this case. This is soon used to remove from
                #the characters list
                user_player = "rachel"
            else:
                print("Invalid input."
                      "Please select one of the possible options (A/B/C)")
    #this statament is the function that removes the defined user_player above,
    #in this case from the characters list. This way, it avoids the user
    #to select the same character more than once as it will no longer going to
    #be available in the characters list
    characters.remove(user_player)

def phoebe():
    global user_lives
    global user_player
    #creating the random option with random.randint
    phoebe_questions = random.randint(0,1)
    if phoebe_questions  == 0:
        print("While not being best friends with her sister, what is the name"
              "of Phoebe's twin sister? \n a. Paula \n b. Susie \n c. Ursula")
        user_input = ""
        while user_input != "c":
            user_input = input(prompt="Select the correct answer:" 
              "(A, B or C)").lower()
            if user_input == "b" or user_input == "a":
                print("Good try, but unfortunately that's incorrect :(")
                user_lives -= 1
                #controlling that if the user no longer has any lives, the 
                #game is over and the restart function is called 
                if user_lives == 0:
                    print("You lost all your lives! Your friends will not be"
                    " reunited." 
                    "\n"
                    "Game over!")
                    restart()
            #determining the correct answer
            elif user_input == "c":
                print("Congrats! This is correct! You now got Phoebe with you!")
                #this function renames the user_player to the selected player,
                #in this case. This is soon used to remove from
                #the characters list
                user_player = "phoebe"
            else:
                print("Invalid input."
                      "Please select one of the possible options (A/B/C)")
    #second option/question to be pulled from the random selection
    else:
        print("What was Phoebe's most famous song?"
            "\n a. Smelly Cat \n b. I'll be there for you \n c. Little Fetus")
        user_input = ""
        while user_input != "a":
            user_input = input(prompt="Select the correct answer:" 
              "(A, B or C)").lower()
            if user_input == "b" or user_input == "c":
                print("Good try, but unfortunately that's incorrect :(")
                user_lives -= 1
                #controlling that if the user no longer has any lives, the 
                #game is over and the restart function is called 
                if user_lives == 0:
                    print("You lost all your lives! Your friends will not be"
                    " reunited." 
                    "\n"
                    "Game over!")
                    restart()
            #determining the correct answer
            elif user_input == "a":
                print("Congrats! This is correct! You now got Phoebe with you!")
                #this function renames the user_player to the selected player,
                #in this case. This is soon used to remove from
                #the characters list
                user_player = "phoebe"
            else:
                print("Invalid input."
                      "Please select one of the possible options (A/B/C)")
    #this statament is the function that removes the defined user_player above,
    #in this case from the characters list. This way, it avoids the user
    #to select the same character more than once as it will no longer going to
    #be available in the characters list
    characters.remove(user_player)

#Creating a dictionary with keys as the user inputs and the values as their 
#corresponding functions that allows the game to pull the function from the 
#selected character
characters_functions = {"joey": joey,
                     "monica": monica,
                     "ross": ross,
                    "chandler": chandler,
                     "rachel": rachel,
                      "phoebe": phoebe
                       }


#The beginning of the game where it introduces the user and the choosen player
def intro():
    #defining global variables as they are also pulled from the character
    #functions above. The character list and the user_lives are determined
    #through the variables below
    global characters
    global user_name
    global user_player
    global user_lives
    characters = ['joey','monica','chandler','phoebe','rachel','ross']
    user_name = ""
    user_player = ""
    user_lives = 3
    #introducing the user player --> making it more personalized
    user_name = input(prompt = "What's your name?").capitalize()
    
    #intro text for the user
    print(f" \
                \033[1m Welcome to New York city, {user_name}! \n \
                Welcome to the F.R.I.E.N.D.S trivia game! \n \
                Let's get the Friends back together! \033[1m ")
    print("*"*80)
    
    #intro to quickly explain the game and prompt for the user to select
    #a character for the user to play with
    user_player = input(prompt = "Choose a character to get started. \n"
        "\n"
        "This is going to be your selected character for the entire \n"
        "game and him/her will look for their friends around New York City \n"
        "so everyone can be back in Central Perk's most famous purple couch.\n"
        "\n"
        "Enter one of the character's name: \n"
        "(Joey, Chandler, Ross, Monica, Rachel, Phoebe) \n ").lower()
    print("*"*80)
    while user_player not in characters:
        print("Invalid character, please try again! \n"
             "\n")
        user_player = input(prompt = "Choose a character to get started. \n"
        "\n"
        "This is going to be your selected character for the entire \n"
        "game and him/her will look for their friends around New York City \n"
        "so everyone can be back in Central Perk's most famous purple couch.\n"
        "\n"
        "Enter one of the character's name: \n"
        "(Joey, Chandler, Ross, Monica, Rachel, Phoebe)\n ").lower()
    #this will make sure that the player selected by the user cannot be used as
    #a character to be find throughout the game
    user_name = user_player
    #this function removes the selected player from the list so it cannot be
    #selected again
    characters.remove(user_player)
    #moves to stage 1
    stage_1()

    
#Stage 1: Search for the first friend 
def stage_1():
    user_player = input(f" This is great {user_name}! \n"
        "\n"
        "Which of your friends do you want to look for first?"
         "\n"
        "(Joey, Chandler, Ross, Monica, Rachel, Phoebe)").lower()
    print("*"*80)
    #if the name is not in the list, it should not be accepted, and try again
    while user_player not in characters:
        print("Invalid character, please try again! \n"
             "\n")
        user_player = input("Which of your friends do you want to look for \
                    first?").lower()
    #if name is on the list, then, it will push the function corresponding to 
    #the selected character
    characters_functions[user_player]()
    #moves to stage 2
    stage_2()

#Stage 3: Search for the second friend 
def stage_2():
    user_player = input(f" Hey {user_name}, so which of your friends is \n"
                "next?"
                "\n"
                "(Joey, Chandler, Ross, Monica, Rachel, Phoebe)").lower()
    print("*"*80)
    while user_player not in characters:
        print("Invalid character, please try again!")
        user_player = input(f" So {user_name}, so which of your friends is \
                    next?").lower()
    #if name is on the list, then, it will push the function corresponding to 
    #the selected character
    characters_functions[user_player]()
    #moves to stage 3
    stage_3()
      
#Stage 3: Search for the third friend 
def stage_3():
    user_player = input("YAY!"
                "\n"
                "You've got half of the crew reunited! Which of the your"
                "friends do you want to rescue now?"
                "\n"
                "(Joey, Chandler, Ross, Monica, Rachel, Phoebe)").lower()
    print("*"*80)
    while user_player not in characters:
        print("Invalid character, please try again!")
        user_player = input(f" YAY!\n"
                    "\n"
        "You've got half of the crew reunited! Which of the your friends do"
        "you want to rescue now?").lower()
    #if name is on the list, then, it will push the function corresponding to 
    #the selected character
    characters_functions[user_player]()
    #moves to stage 4
    stage_4()
            
#Stage 4: Search for the fourth friend 
def stage_4():
    user_player = input(f"Two more friends wondering around the city... \n"
                "\n"
                "Who is the next lucky one?"
                 "\n"
                "(Joey, Chandler, Ross, Monica, Rachel, Phoebe)").lower()
    print("*"*80)
    while user_player not in characters:
        print("Invalid character, please try again!")
        user_player = input(f" Two more friends wondering around the city... \
        Who is the next lucky one?").lower()
    #if name is on the list, then, it will push the function corresponding to 
    #the selected character
    characters_functions[user_player]()
    #moves to stage 5
    stage_5()
    
#Stage 5: Search for the fifth and final friend 
def stage_5():
    user_player = input(f"FRIENDS is almost complete!\n"
                "\n"
                "Who is the only friend missing?"
                "\n"
                "(Joey, Chandler, Ross, Monica, Rachel, Phoebe)").lower()
    print("*"*80)
    while user_player not in characters:
        print("Invalid character, please try again!")
        user_player = input(f" FRIENDS is almost complete!" 
                    "/n"
                    "Who is the only friend missing?").lower()
    #if name is on the list, then, it will push the function corresponding to 
    #the selected character
    characters_functions[user_player]()
    print("*"*80)
    #all characters are reunited and the user has won the game
    print(f" \033[1m \
                  Congratulations {user_name}!"
                             "\n"
                          "You win!")
    print("*"*80)
    #option to the user to restart the game
    restart()


#Start the game
intro()
